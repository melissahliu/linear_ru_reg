# %%
import pdb
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
import torch
from torch.utils.data import DataLoader, Dataset, TensorDataset
from torch import nn, optim
from torch.autograd import Variable
import pytorch_lightning as pl
from pytorch_lightning import Trainer
from pytorch_lightning.callbacks import ModelCheckpoint

# %%
def generate_shift_one_dim_dataset(n, p, q, seed):
    rng = np.random.RandomState(seed)
    
    us1 = rng.binomial(n=1, p=p, size=int(n * q))
    xs1 = rng.uniform(0.0, 10.0, size=int(n * q))
    noise1 = rng.normal(0.0, 20.0, size=int(n * q))
    ys1 = xs1 * xs1 * xs1 + 1 * xs1 * xs1 * xs1 * us1 + noise1
    
    us2 = rng.binomial(n=1, p=p, size=int(n * (1 - q)))
    xs2 = rng.uniform(0.0, 1.0, size=int(n * (1 - q)))
    noise2 = rng.normal(0.0, 20.0, size=int(n * (1 - q)))
    ys2 = xs2 * xs2 * xs2 + 1 * xs2 * xs2 * xs2 * us2 + noise2
    
    xs = np.concatenate((xs1, xs2))
    ys = np.concatenate((ys1, ys2))
    return xs.reshape(-1, 1), ys.reshape(-1, 1)

# %%
def standardize(data):
    mu = data.mean(axis=0, keepdims=1)
    scale = data.std(axis=0, keepdims=1)
    # scale[scale < 1e-10] = 1.0
    data = (data - mu) / scale
    return data, mu, scale

# %%
def get_dataloaders(
    X_unstandardized, y_unstandardized, X_train, y_train, X_val, y_val, X_tests, y_tests, seed,
):
    X_train, x_train_mu, x_train_scale = standardize(X_train)
    y_train, y_train_mu, y_train_scale = standardize(y_train)
    
    X_val = (X_val - x_train_mu) / x_train_scale
    y_val = (y_val - y_train_mu) / y_train_scale
    
    for i in range(len(y_tests)):
        y_tests[i] = (y_tests[i] - y_train_mu) / y_train_scale
        X_tests[i] = (X_tests[i] - x_train_mu) / x_train_scale

    x_train_mu = x_train_mu.item()
    x_train_scale = x_train_scale.item()
    y_train_mu = y_train_mu.item()
    y_train_scale = y_train_scale.item()
    
    train = TensorDataset(
        torch.Tensor(X_train),
        torch.Tensor(y_train),
    )
    train_loader = DataLoader(
        train, batch_size=int(X_train.shape[0] * 0.25), shuffle=True
    )

    val = TensorDataset(
        torch.Tensor(X_val),
        torch.Tensor(y_val),
    )
    val_loader = DataLoader(val, batch_size=len(val), shuffle=False)

    test_loaders = []
    for i in range(len(y_tests)):
        test = TensorDataset(
            torch.Tensor(X_tests[i]),
            torch.Tensor(y_tests[i]),
        )
        test_loader = DataLoader(test, batch_size=len(test), shuffle=False)
        test_loaders.append(test_loader)

    return (
        X_unstandardized,
        y_unstandardized,
        train_loader,
        val_loader,
        test_loaders,
        X_train[0].shape[0],
        x_train_mu,
        x_train_scale,
        y_train_mu,
        y_train_scale,
    )

# %%
def get_shift_one_dim_dataloaders(
    n_train, seed, p_train, q_train, p_tests, q_tests
):
    X_train = []
    y_train = []
    
    X_val, y_val = generate_shift_one_dim_dataset(
        n=int(n_train * 0.2), p=p_train, q=q_train, seed=seed
    )
    
    X_tests = []
    y_tests = []
    X_unstandardized = []
    y_unstandardized = []
    for q_test in q_tests:
        for p_test in p_tests:
            X_test, y_test = generate_shift_one_dim_dataset(
                n=10000, p=p_test, q=q_test, seed=seed + 1
            )
            X_tests.append(X_test)
            y_tests.append(y_test)
            X_unstandardized.append(X_test)
            y_unstandardized.append(y_test)
            if (q_test == 0.5 and p_test == 0.5):
                X_train = X_test
                y_train = y_test
    
    return (
        get_dataloaders(X_unstandardized, y_unstandardized, X_train, y_train, X_val, y_val, X_tests, y_tests, seed)
    )

# %%
p_tests = [0.5, 0.9]
q_tests = [1, 0.5, 0.1]
X_unstandardized, y_unstandardized, train_loader, val_loader, test_loaders, X_train_shape, x_train_mu, x_train_scale, y_train_mu, y_train_scale = get_shift_one_dim_dataloaders(n_train=7000, seed=42, p_train=0.5, q_train=0.5, p_tests=p_tests, q_tests=q_tests)

# %%
l_rate = 0.01 #appropriate learning rate? 1e-2 or 1e-3
mse_loss = nn.MSELoss(reduction = 'mean')

# %%
class Regression(pl.LightningModule):
    def __init__(self):
        super(Regression, self).__init__()
        self.fc1 = nn.Linear(1, 1) #how many layers and what size?
        self.validation_losses = []
        self.test_losses = []

    def forward(self, x):
        x = self.fc1(x)  # No activation function?
        return x
    
    def configure_optimizers(self):
        return optim.Adam(self.parameters(), lr=l_rate) #adam optimizer
    
    def training_step(self, batch, batch_idx):
        breakpoint()
        x, y = batch
        logits = self.forward(x)
        loss = mse_loss(logits, y)
        logs = {'loss': loss}
        print(loss)
        return {'loss': loss, 'log': logs}
    
    def validation_step(self, batch, batch_idx):
        breakpoint()
        x, y = batch
        logits = self.forward(x)
        loss = mse_loss(logits, y)
        self.log('val_loss', loss) #why do i get error message w/o this line
        self.validation_losses.append(loss.item())
        print(loss)
        return loss

    def on_validation_epoch_end(self):
        breakpoint()
        avg_loss = sum(self.validation_losses) / len(self.validation_losses)
        tensorboard_logs = {'val_loss': avg_loss}
        self.log('avg_val_loss', avg_loss, on_epoch=True, prog_bar=True)
        
    def test_step(self, batch, batch_idx):
        breakpoint()
        x, y = batch
        logits = self.forward(x)
        loss = mse_loss(logits, y)
        predictions.append(logits)
        self.test_losses.append(loss.item())
        return loss
    
    def on_test_epoch_end(self):
        breakpoint()
        avg_loss = sum(self.test_losses) / len(self.test_losses)
        logs = {'test_loss': avg_loss}      
        avg_losses.append(avg_loss)
        return avg_loss

# %%
model = Regression()
checkpoint_callback = ModelCheckpoint(monitor='val_loss', dirpath='checkpoints/')
trainer = Trainer(max_epochs = 100, callbacks=[checkpoint_callback]) #epochs
trainer.fit(model, train_dataloaders=train_loader, val_dataloaders=val_loader) #comment out dataloader functions and make loop and pass dataloaders
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
#
#   | Name | Type   | Params
# --------------------------------
# 0 | fc1  | Linear | 2
# --------------------------------
# 2         Trainable params
# 0         Non-trainable params
# 2         Total params
# 0.000     Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# tensor(1.5690)
# Training: 0it [00:00, ?it/s]
# tensor(1.5434, grad_fn=<MseLossBackward0>)
# tensor(1.5359, grad_fn=<MseLossBackward0>)
# tensor(1.4685, grad_fn=<MseLossBackward0>)
# tensor(1.4122, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(1.4584)
# tensor(1.4104, grad_fn=<MseLossBackward0>)
# tensor(1.3989, grad_fn=<MseLossBackward0>)
# tensor(1.4838, grad_fn=<MseLossBackward0>)
# tensor(1.2385, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(1.3549)
# tensor(1.2237, grad_fn=<MseLossBackward0>)
# tensor(1.2845, grad_fn=<MseLossBackward0>)
# tensor(1.2551, grad_fn=<MseLossBackward0>)
# tensor(1.3643, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(1.2586)
# tensor(1.2291, grad_fn=<MseLossBackward0>)
# tensor(1.3040, grad_fn=<MseLossBackward0>)
# tensor(1.0925, grad_fn=<MseLossBackward0>)
# tensor(1.1378, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(1.1692)
# tensor(1.1907, grad_fn=<MseLossBackward0>)
# tensor(1.0525, grad_fn=<MseLossBackward0>)
# tensor(1.0471, grad_fn=<MseLossBackward0>)
# tensor(1.1289, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(1.0872)
# tensor(1.0422, grad_fn=<MseLossBackward0>)
# tensor(1.1158, grad_fn=<MseLossBackward0>)
# tensor(0.9832, grad_fn=<MseLossBackward0>)
# tensor(0.9656, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(1.0121)
# tensor(1.0087, grad_fn=<MseLossBackward0>)
# tensor(0.8977, grad_fn=<MseLossBackward0>)
# tensor(0.9249, grad_fn=<MseLossBackward0>)
# tensor(0.9881, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.9437)
# tensor(0.8965, grad_fn=<MseLossBackward0>)
# tensor(0.9690, grad_fn=<MseLossBackward0>)
# tensor(0.8134, grad_fn=<MseLossBackward0>)
# tensor(0.8818, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.8813)
# tensor(0.8541, grad_fn=<MseLossBackward0>)
# tensor(0.8543, grad_fn=<MseLossBackward0>)
# tensor(0.8147, grad_fn=<MseLossBackward0>)
# tensor(0.8000, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.8244)
# tensor(0.7649, grad_fn=<MseLossBackward0>)
# tensor(0.8162, grad_fn=<MseLossBackward0>)
# tensor(0.7860, grad_fn=<MseLossBackward0>)
# tensor(0.7402, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.7725)
# tensor(0.7858, grad_fn=<MseLossBackward0>)
# tensor(0.7276, grad_fn=<MseLossBackward0>)
# tensor(0.7289, grad_fn=<MseLossBackward0>)
# tensor(0.6698, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.7249)
# tensor(0.6875, grad_fn=<MseLossBackward0>)
# tensor(0.6297, grad_fn=<MseLossBackward0>)
# tensor(0.6900, grad_fn=<MseLossBackward0>)
# tensor(0.7211, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.6815)
# tensor(0.6136, grad_fn=<MseLossBackward0>)
# tensor(0.6555, grad_fn=<MseLossBackward0>)
# tensor(0.7090, grad_fn=<MseLossBackward0>)
# tensor(0.5864, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.6414)
# tensor(0.6851, grad_fn=<MseLossBackward0>)
# tensor(0.5599, grad_fn=<MseLossBackward0>)
# tensor(0.6005, grad_fn=<MseLossBackward0>)
# tensor(0.5678, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.6046)
# tensor(0.5823, grad_fn=<MseLossBackward0>)
# tensor(0.5614, grad_fn=<MseLossBackward0>)
# tensor(0.5499, grad_fn=<MseLossBackward0>)
# tensor(0.5787, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.5710)
# tensor(0.5547, grad_fn=<MseLossBackward0>)
# tensor(0.5064, grad_fn=<MseLossBackward0>)
# tensor(0.5619, grad_fn=<MseLossBackward0>)
# tensor(0.5221, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.5402)
# tensor(0.4832, grad_fn=<MseLossBackward0>)
# tensor(0.4874, grad_fn=<MseLossBackward0>)
# tensor(0.5436, grad_fn=<MseLossBackward0>)
# tensor(0.5136, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.5122)
# tensor(0.4667, grad_fn=<MseLossBackward0>)
# tensor(0.5182, grad_fn=<MseLossBackward0>)
# tensor(0.5017, grad_fn=<MseLossBackward0>)
# tensor(0.4362, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.4866)
# tensor(0.4628, grad_fn=<MseLossBackward0>)
# tensor(0.4451, grad_fn=<MseLossBackward0>)
# tensor(0.4465, grad_fn=<MseLossBackward0>)
# tensor(0.4714, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.4635)
# tensor(0.4585, grad_fn=<MseLossBackward0>)
# tensor(0.4005, grad_fn=<MseLossBackward0>)
# tensor(0.4164, grad_fn=<MseLossBackward0>)
# tensor(0.4630, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.4427)
# tensor(0.4353, grad_fn=<MseLossBackward0>)
# tensor(0.4055, grad_fn=<MseLossBackward0>)
# tensor(0.4477, grad_fn=<MseLossBackward0>)
# tensor(0.3727, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.4238)
# tensor(0.4044, grad_fn=<MseLossBackward0>)
# tensor(0.3838, grad_fn=<MseLossBackward0>)
# tensor(0.3886, grad_fn=<MseLossBackward0>)
# tensor(0.4131, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.4069)
# tensor(0.3567, grad_fn=<MseLossBackward0>)
# tensor(0.3827, grad_fn=<MseLossBackward0>)
# tensor(0.3884, grad_fn=<MseLossBackward0>)
# tensor(0.3984, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.3919)
# tensor(0.3804, grad_fn=<MseLossBackward0>)
# tensor(0.3899, grad_fn=<MseLossBackward0>)
# tensor(0.3600, grad_fn=<MseLossBackward0>)
# tensor(0.3409, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.3784)
# tensor(0.3518, grad_fn=<MseLossBackward0>)
# tensor(0.3547, grad_fn=<MseLossBackward0>)
# tensor(0.3448, grad_fn=<MseLossBackward0>)
# tensor(0.3691, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.3663)
# tensor(0.3534, grad_fn=<MseLossBackward0>)
# tensor(0.3707, grad_fn=<MseLossBackward0>)
# tensor(0.3356, grad_fn=<MseLossBackward0>)
# tensor(0.3168, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.3556)
# tensor(0.3660, grad_fn=<MseLossBackward0>)
# tensor(0.3432, grad_fn=<MseLossBackward0>)
# tensor(0.3061, grad_fn=<MseLossBackward0>)
# tensor(0.3217, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.3462)
# tensor(0.3483, grad_fn=<MseLossBackward0>)
# tensor(0.3148, grad_fn=<MseLossBackward0>)
# tensor(0.2998, grad_fn=<MseLossBackward0>)
# tensor(0.3388, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.3379)
# tensor(0.3228, grad_fn=<MseLossBackward0>)
# tensor(0.3042, grad_fn=<MseLossBackward0>)
# tensor(0.3292, grad_fn=<MseLossBackward0>)
# tensor(0.3149, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.3306)
# tensor(0.2966, grad_fn=<MseLossBackward0>)
# tensor(0.3185, grad_fn=<MseLossBackward0>)
# tensor(0.3111, grad_fn=<MseLossBackward0>)
# tensor(0.3181, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.3243)
# tensor(0.3156, grad_fn=<MseLossBackward0>)
# tensor(0.2934, grad_fn=<MseLossBackward0>)
# tensor(0.3073, grad_fn=<MseLossBackward0>)
# tensor(0.3052, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.3187)
# tensor(0.3133, grad_fn=<MseLossBackward0>)
# tensor(0.2950, grad_fn=<MseLossBackward0>)
# tensor(0.3193, grad_fn=<MseLossBackward0>)
# tensor(0.2736, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.3138)
# tensor(0.3047, grad_fn=<MseLossBackward0>)
# tensor(0.2989, grad_fn=<MseLossBackward0>)
# tensor(0.2862, grad_fn=<MseLossBackward0>)
# tensor(0.2938, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.3096)
# tensor(0.2846, grad_fn=<MseLossBackward0>)
# tensor(0.2929, grad_fn=<MseLossBackward0>)
# tensor(0.3026, grad_fn=<MseLossBackward0>)
# tensor(0.2882, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.3059)
# tensor(0.2899, grad_fn=<MseLossBackward0>)
# tensor(0.2891, grad_fn=<MseLossBackward0>)
# tensor(0.2761, grad_fn=<MseLossBackward0>)
# tensor(0.3003, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.3028)
# tensor(0.3170, grad_fn=<MseLossBackward0>)
# tensor(0.2828, grad_fn=<MseLossBackward0>)
# tensor(0.2767, grad_fn=<MseLossBackward0>)
# tensor(0.2679, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.3001)
# tensor(0.2726, grad_fn=<MseLossBackward0>)
# tensor(0.2858, grad_fn=<MseLossBackward0>)
# tensor(0.2964, grad_fn=<MseLossBackward0>)
# tensor(0.2794, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2978)
# tensor(0.2690, grad_fn=<MseLossBackward0>)
# tensor(0.2894, grad_fn=<MseLossBackward0>)
# tensor(0.2898, grad_fn=<MseLossBackward0>)
# tensor(0.2781, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2958)
# tensor(0.3047, grad_fn=<MseLossBackward0>)
# tensor(0.2690, grad_fn=<MseLossBackward0>)
# tensor(0.2687, grad_fn=<MseLossBackward0>)
# tensor(0.2775, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2941)
# tensor(0.2946, grad_fn=<MseLossBackward0>)
# tensor(0.2750, grad_fn=<MseLossBackward0>)
# tensor(0.2711, grad_fn=<MseLossBackward0>)
# tensor(0.2731, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2926)
# tensor(0.2750, grad_fn=<MseLossBackward0>)
# tensor(0.2745, grad_fn=<MseLossBackward0>)
# tensor(0.2628, grad_fn=<MseLossBackward0>)
# tensor(0.2964, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2914)
# tensor(0.2678, grad_fn=<MseLossBackward0>)
# tensor(0.3029, grad_fn=<MseLossBackward0>)
# tensor(0.2745, grad_fn=<MseLossBackward0>)
# tensor(0.2595, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2904)
# tensor(0.2808, grad_fn=<MseLossBackward0>)
# tensor(0.2911, grad_fn=<MseLossBackward0>)
# tensor(0.2449, grad_fn=<MseLossBackward0>)
# tensor(0.2844, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2895)
# tensor(0.2751, grad_fn=<MseLossBackward0>)
# tensor(0.2823, grad_fn=<MseLossBackward0>)
# tensor(0.2872, grad_fn=<MseLossBackward0>)
# tensor(0.2537, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2888)
# tensor(0.2979, grad_fn=<MseLossBackward0>)
# tensor(0.2622, grad_fn=<MseLossBackward0>)
# tensor(0.2618, grad_fn=<MseLossBackward0>)
# tensor(0.2741, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2882)
# tensor(0.3053, grad_fn=<MseLossBackward0>)
# tensor(0.2461, grad_fn=<MseLossBackward0>)
# tensor(0.2881, grad_fn=<MseLossBackward0>)
# tensor(0.2546, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2877)
# tensor(0.2695, grad_fn=<MseLossBackward0>)
# tensor(0.2740, grad_fn=<MseLossBackward0>)
# tensor(0.2808, grad_fn=<MseLossBackward0>)
# tensor(0.2680, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2873)
# tensor(0.2511, grad_fn=<MseLossBackward0>)
# tensor(0.3041, grad_fn=<MseLossBackward0>)
# tensor(0.2858, grad_fn=<MseLossBackward0>)
# tensor(0.2502, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2869)
# tensor(0.3013, grad_fn=<MseLossBackward0>)
# tensor(0.2596, grad_fn=<MseLossBackward0>)
# tensor(0.2602, grad_fn=<MseLossBackward0>)
# tensor(0.2689, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2866)
# tensor(0.2497, grad_fn=<MseLossBackward0>)
# tensor(0.2906, grad_fn=<MseLossBackward0>)
# tensor(0.2788, grad_fn=<MseLossBackward0>)
# tensor(0.2700, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2864)
# tensor(0.2706, grad_fn=<MseLossBackward0>)
# tensor(0.2525, grad_fn=<MseLossBackward0>)
# tensor(0.2954, grad_fn=<MseLossBackward0>)
# tensor(0.2699, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2862)
# tensor(0.2745, grad_fn=<MseLossBackward0>)
# tensor(0.2810, grad_fn=<MseLossBackward0>)
# tensor(0.2676, grad_fn=<MseLossBackward0>)
# tensor(0.2648, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2860)
# tensor(0.2816, grad_fn=<MseLossBackward0>)
# tensor(0.2540, grad_fn=<MseLossBackward0>)
# tensor(0.2782, grad_fn=<MseLossBackward0>)
# tensor(0.2736, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2859)
# tensor(0.2887, grad_fn=<MseLossBackward0>)
# tensor(0.2762, grad_fn=<MseLossBackward0>)
# tensor(0.2850, grad_fn=<MseLossBackward0>)
# tensor(0.2372, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2857)
# tensor(0.3005, grad_fn=<MseLossBackward0>)
# tensor(0.2726, grad_fn=<MseLossBackward0>)
# tensor(0.2551, grad_fn=<MseLossBackward0>)
# tensor(0.2586, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2856)
# tensor(0.2648, grad_fn=<MseLossBackward0>)
# tensor(0.2663, grad_fn=<MseLossBackward0>)
# tensor(0.2839, grad_fn=<MseLossBackward0>)
# tensor(0.2714, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2856)
# tensor(0.2692, grad_fn=<MseLossBackward0>)
# tensor(0.2624, grad_fn=<MseLossBackward0>)
# tensor(0.2872, grad_fn=<MseLossBackward0>)
# tensor(0.2675, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2855)
# tensor(0.2693, grad_fn=<MseLossBackward0>)
# tensor(0.2580, grad_fn=<MseLossBackward0>)
# tensor(0.2998, grad_fn=<MseLossBackward0>)
# tensor(0.2590, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2855)
# tensor(0.2698, grad_fn=<MseLossBackward0>)
# tensor(0.2823, grad_fn=<MseLossBackward0>)
# tensor(0.2820, grad_fn=<MseLossBackward0>)
# tensor(0.2519, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2854)
# tensor(0.2987, grad_fn=<MseLossBackward0>)
# tensor(0.2583, grad_fn=<MseLossBackward0>)
# tensor(0.2604, grad_fn=<MseLossBackward0>)
# tensor(0.2686, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2854)
# tensor(0.2729, grad_fn=<MseLossBackward0>)
# tensor(0.2659, grad_fn=<MseLossBackward0>)
# tensor(0.2666, grad_fn=<MseLossBackward0>)
# tensor(0.2804, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2854)
# tensor(0.2812, grad_fn=<MseLossBackward0>)
# tensor(0.2633, grad_fn=<MseLossBackward0>)
# tensor(0.2558, grad_fn=<MseLossBackward0>)
# tensor(0.2854, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2853)
# tensor(0.2695, grad_fn=<MseLossBackward0>)
# tensor(0.2551, grad_fn=<MseLossBackward0>)
# tensor(0.2823, grad_fn=<MseLossBackward0>)
# tensor(0.2789, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2853)
# tensor(0.2403, grad_fn=<MseLossBackward0>)
# tensor(0.2808, grad_fn=<MseLossBackward0>)
# tensor(0.2875, grad_fn=<MseLossBackward0>)
# tensor(0.2771, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2853)
# tensor(0.2554, grad_fn=<MseLossBackward0>)
# tensor(0.2910, grad_fn=<MseLossBackward0>)
# tensor(0.2594, grad_fn=<MseLossBackward0>)
# tensor(0.2798, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2853)
# tensor(0.2429, grad_fn=<MseLossBackward0>)
# tensor(0.2615, grad_fn=<MseLossBackward0>)
# tensor(0.2792, grad_fn=<MseLossBackward0>)
# tensor(0.3020, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2853)
# tensor(0.2682, grad_fn=<MseLossBackward0>)
# tensor(0.2505, grad_fn=<MseLossBackward0>)
# tensor(0.2925, grad_fn=<MseLossBackward0>)
# tensor(0.2745, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2853)
# tensor(0.2911, grad_fn=<MseLossBackward0>)
# tensor(0.2618, grad_fn=<MseLossBackward0>)
# tensor(0.2618, grad_fn=<MseLossBackward0>)
# tensor(0.2709, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2852)
# tensor(0.2626, grad_fn=<MseLossBackward0>)
# tensor(0.2656, grad_fn=<MseLossBackward0>)
# tensor(0.2679, grad_fn=<MseLossBackward0>)
# tensor(0.2895, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2852)
# tensor(0.2777, grad_fn=<MseLossBackward0>)
# tensor(0.2714, grad_fn=<MseLossBackward0>)
# tensor(0.2758, grad_fn=<MseLossBackward0>)
# tensor(0.2608, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2852)
# tensor(0.2823, grad_fn=<MseLossBackward0>)
# tensor(0.2764, grad_fn=<MseLossBackward0>)
# tensor(0.2546, grad_fn=<MseLossBackward0>)
# tensor(0.2724, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2852)
# tensor(0.2714, grad_fn=<MseLossBackward0>)
# tensor(0.2647, grad_fn=<MseLossBackward0>)
# tensor(0.2798, grad_fn=<MseLossBackward0>)
# tensor(0.2697, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2852)
# tensor(0.2577, grad_fn=<MseLossBackward0>)
# tensor(0.2888, grad_fn=<MseLossBackward0>)
# tensor(0.2533, grad_fn=<MseLossBackward0>)
# tensor(0.2858, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2852)
# tensor(0.2729, grad_fn=<MseLossBackward0>)
# tensor(0.2691, grad_fn=<MseLossBackward0>)
# tensor(0.2766, grad_fn=<MseLossBackward0>)
# tensor(0.2671, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2852)
# tensor(0.2650, grad_fn=<MseLossBackward0>)
# tensor(0.2570, grad_fn=<MseLossBackward0>)
# tensor(0.2907, grad_fn=<MseLossBackward0>)
# tensor(0.2729, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2852)
# tensor(0.2745, grad_fn=<MseLossBackward0>)
# tensor(0.2743, grad_fn=<MseLossBackward0>)
# tensor(0.2623, grad_fn=<MseLossBackward0>)
# tensor(0.2745, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2852)
# tensor(0.2511, grad_fn=<MseLossBackward0>)
# tensor(0.2706, grad_fn=<MseLossBackward0>)
# tensor(0.2865, grad_fn=<MseLossBackward0>)
# tensor(0.2774, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2852)
# tensor(0.2778, grad_fn=<MseLossBackward0>)
# tensor(0.2469, grad_fn=<MseLossBackward0>)
# tensor(0.2791, grad_fn=<MseLossBackward0>)
# tensor(0.2818, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2852)
# tensor(0.2651, grad_fn=<MseLossBackward0>)
# tensor(0.2740, grad_fn=<MseLossBackward0>)
# tensor(0.2601, grad_fn=<MseLossBackward0>)
# tensor(0.2865, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2852)
# tensor(0.2587, grad_fn=<MseLossBackward0>)
# tensor(0.2717, grad_fn=<MseLossBackward0>)
# tensor(0.2755, grad_fn=<MseLossBackward0>)
# tensor(0.2796, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2852)
# tensor(0.2584, grad_fn=<MseLossBackward0>)
# tensor(0.2772, grad_fn=<MseLossBackward0>)
# tensor(0.2886, grad_fn=<MseLossBackward0>)
# tensor(0.2614, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2852)
# tensor(0.2676, grad_fn=<MseLossBackward0>)
# tensor(0.2659, grad_fn=<MseLossBackward0>)
# tensor(0.2652, grad_fn=<MseLossBackward0>)
# tensor(0.2869, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2852)
# tensor(0.2813, grad_fn=<MseLossBackward0>)
# tensor(0.2621, grad_fn=<MseLossBackward0>)
# tensor(0.2655, grad_fn=<MseLossBackward0>)
# tensor(0.2767, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2852)
# tensor(0.2594, grad_fn=<MseLossBackward0>)
# tensor(0.2768, grad_fn=<MseLossBackward0>)
# tensor(0.2878, grad_fn=<MseLossBackward0>)
# tensor(0.2617, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2852)
# tensor(0.2798, grad_fn=<MseLossBackward0>)
# tensor(0.2753, grad_fn=<MseLossBackward0>)
# tensor(0.2617, grad_fn=<MseLossBackward0>)
# tensor(0.2688, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2852)
# tensor(0.2745, grad_fn=<MseLossBackward0>)
# tensor(0.2826, grad_fn=<MseLossBackward0>)
# tensor(0.2572, grad_fn=<MseLossBackward0>)
# tensor(0.2713, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2852)
# tensor(0.2833, grad_fn=<MseLossBackward0>)
# tensor(0.2709, grad_fn=<MseLossBackward0>)
# tensor(0.2781, grad_fn=<MseLossBackward0>)
# tensor(0.2533, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2852)
# tensor(0.2703, grad_fn=<MseLossBackward0>)
# tensor(0.2631, grad_fn=<MseLossBackward0>)
# tensor(0.2860, grad_fn=<MseLossBackward0>)
# tensor(0.2663, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2852)
# tensor(0.2854, grad_fn=<MseLossBackward0>)
# tensor(0.2602, grad_fn=<MseLossBackward0>)
# tensor(0.2662, grad_fn=<MseLossBackward0>)
# tensor(0.2738, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2852)
# tensor(0.2553, grad_fn=<MseLossBackward0>)
# tensor(0.2948, grad_fn=<MseLossBackward0>)
# tensor(0.2755, grad_fn=<MseLossBackward0>)
# tensor(0.2600, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2852)
# tensor(0.3059, grad_fn=<MseLossBackward0>)
# tensor(0.2558, grad_fn=<MseLossBackward0>)
# tensor(0.2847, grad_fn=<MseLossBackward0>)
# tensor(0.2393, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2852)
# tensor(0.2605, grad_fn=<MseLossBackward0>)
# tensor(0.2688, grad_fn=<MseLossBackward0>)
# tensor(0.2832, grad_fn=<MseLossBackward0>)
# tensor(0.2731, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2852)
# tensor(0.2550, grad_fn=<MseLossBackward0>)
# tensor(0.2782, grad_fn=<MseLossBackward0>)
# tensor(0.3048, grad_fn=<MseLossBackward0>)
# tensor(0.2476, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2852)
# tensor(0.2764, grad_fn=<MseLossBackward0>)
# tensor(0.2830, grad_fn=<MseLossBackward0>)
# tensor(0.2651, grad_fn=<MseLossBackward0>)
# tensor(0.2611, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2852)
# tensor(0.2491, grad_fn=<MseLossBackward0>)
# tensor(0.2938, grad_fn=<MseLossBackward0>)
# tensor(0.2952, grad_fn=<MseLossBackward0>)
# tensor(0.2476, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2852)
# tensor(0.2823, grad_fn=<MseLossBackward0>)
# tensor(0.2704, grad_fn=<MseLossBackward0>)
# tensor(0.2533, grad_fn=<MseLossBackward0>)
# tensor(0.2797, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2852)
# tensor(0.2648, grad_fn=<MseLossBackward0>)
# tensor(0.2775, grad_fn=<MseLossBackward0>)
# tensor(0.2638, grad_fn=<MseLossBackward0>)
# tensor(0.2796, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2852)
# tensor(0.2636, grad_fn=<MseLossBackward0>)
# tensor(0.2609, grad_fn=<MseLossBackward0>)
# tensor(0.2859, grad_fn=<MseLossBackward0>)
# tensor(0.2753, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2852)
# tensor(0.2690, grad_fn=<MseLossBackward0>)
# tensor(0.2528, grad_fn=<MseLossBackward0>)
# tensor(0.2765, grad_fn=<MseLossBackward0>)
# tensor(0.2874, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# tensor(0.2852)
# tensor(0.2595, grad_fn=<MseLossBackward0>)
# tensor(0.2592, grad_fn=<MseLossBackward0>)
# tensor(0.2514, grad_fn=<MseLossBackward0>)
# tensor(0.3155, grad_fn=<MseLossBackward0>)
# Validation: 0it [00:00, ?it/s]
# `Trainer.fit` stopped: `max_epochs=100` reached.
# tensor(0.2852)

# %%
predictions = []
avg_losses = []
for i, test_loader in enumerate(test_loaders):
    trainer.test(dataloaders=test_loader, ckpt_path="best")
avg_losses
# Out:
# Restoring states from the checkpoint path at /home/groups/swager/mliu1785/linear_ru_reg/checkpoints/checkpoints/checkpoints/epoch=82-step=332.ckpt
# Loaded model weights from the checkpoint at /home/groups/swager/mliu1785/linear_ru_reg/checkpoints/checkpoints/checkpoints/epoch=82-step=332.ckpt
# Testing: 0it [00:00, ?it/s]
# Restoring states from the checkpoint path at /home/groups/swager/mliu1785/linear_ru_reg/checkpoints/checkpoints/checkpoints/epoch=82-step=332.ckpt
# Loaded model weights from the checkpoint at /home/groups/swager/mliu1785/linear_ru_reg/checkpoints/checkpoints/checkpoints/epoch=82-step=332.ckpt
# Testing: 0it [00:00, ?it/s]
# Restoring states from the checkpoint path at /home/groups/swager/mliu1785/linear_ru_reg/checkpoints/checkpoints/checkpoints/epoch=82-step=332.ckpt
# Loaded model weights from the checkpoint at /home/groups/swager/mliu1785/linear_ru_reg/checkpoints/checkpoints/checkpoints/epoch=82-step=332.ckpt
# Testing: 0it [00:00, ?it/s]
# Restoring states from the checkpoint path at /home/groups/swager/mliu1785/linear_ru_reg/checkpoints/checkpoints/checkpoints/epoch=82-step=332.ckpt
# Loaded model weights from the checkpoint at /home/groups/swager/mliu1785/linear_ru_reg/checkpoints/checkpoints/checkpoints/epoch=82-step=332.ckpt
# Testing: 0it [00:00, ?it/s]
# Restoring states from the checkpoint path at /home/groups/swager/mliu1785/linear_ru_reg/checkpoints/checkpoints/checkpoints/epoch=82-step=332.ckpt
# Loaded model weights from the checkpoint at /home/groups/swager/mliu1785/linear_ru_reg/checkpoints/checkpoints/checkpoints/epoch=82-step=332.ckpt
# Testing: 0it [00:00, ?it/s]
# Restoring states from the checkpoint path at /home/groups/swager/mliu1785/linear_ru_reg/checkpoints/checkpoints/checkpoints/epoch=82-step=332.ckpt
# Loaded model weights from the checkpoint at /home/groups/swager/mliu1785/linear_ru_reg/checkpoints/checkpoints/checkpoints/epoch=82-step=332.ckpt
# Testing: 0it [00:00, ?it/s]
# [0.5087902545928955,
#  0.5775391161441803,
#  0.47549336155255634,
#  0.44264402985572815,
#  0.3695111349225044,
#  0.3223221997419993]

# %%
plot_pred = []
for i in range(len(X_unstandardized)):
    test_pred = []
    for j in range(0,2):
        pred = predictions[i][j].item() * y_train_scale + y_train_mu
        test_pred.append(pred)
    plot_pred.append(test_pred)
plot_pred
# Out:
# [[475.34560716866366, -74.79515488166032],
#  [475.34560716866366, -74.79515488166032],
#  [617.0127232073676, 172.3301023079232],
#  [617.0127232073676, 172.3301023079232],
#  [451.63440754689964, 19.15308874882541],
#  [451.63440754689964, 19.15308874882541]]

# %%
# %ls
# Out:
# checkpoints/  epoch=83-step=336.ckpt  epoch=94-step=380.ckpt  lightning_logs/

# %%
trained_model = Regression.load_from_checkpoint('epoch=94-step=380.ckpt')
trained_model.eval()
x1 = 0
x2 = 10
x1_tensor = torch.tensor([[(x1 - x_train_mu) / x_train_scale]], dtype=torch.float32)
x2_tensor = torch.tensor([[(x2 - x_train_mu) / x_train_scale]], dtype=torch.float32) 
with torch.no_grad():
    y1 = trained_model(x1_tensor)[0][0].item() * y_train_scale + y_train_mu
    y2 = trained_model(x2_tensor)[0][0].item() * y_train_scale + y_train_mu
y1, y2
# Out:
# (-104.50191740932291, 964.4882659931523)

# %%
fig, ax = plt.subplots(3, 2, figsize=(20, 20))
ax = ax.flatten();
for i in range(len(X_unstandardized)):
    ax[i].scatter(X_unstandardized[i], y_unstandardized[i], alpha=0.2)
    ax[i].set_title(r"$p={}$".format(round(p_tests[i % 2], 3)) + " and " + r"$q={}$".format(round(q_tests[int(i / 2)], 3)), fontsize=20)
    ax[i].set_xlabel(r"$x$", fontsize=20)
    ax[i].set_ylabel(r"$y$", fontsize=20)
    ax[i].set_ylim(0, 1500)
    
    lobf = LinearRegression()
    lobf.fit(X_unstandardized[i], y_unstandardized[i])
    print(lobf.coef_)
    y_pred = lobf.predict(X_unstandardized[i])
    ax[i].plot(X_unstandardized[i], y_pred, color='red', label='Linear Regression')
    
    first_two = X_unstandardized[i][:2]
    model = LinearRegression()
    model.fit(first_two, plot_pred[i])
    print(model.coef_)
    model_pred = model.predict(first_two)
    ax[i].plot(first_two, model_pred, color='black', label='Linear Regression')
    
    ax[i].plot([x1, x2], [y1, y2], marker='o', label='Points')
plt.suptitle("Comparing Model Predictions with Linear Regression", fontsize=25)
plt.savefig("modelpred_vs_linearreg.png")
plt.tight_layout()
# Out:
# [[136.57229683]]
# [106.95821366]
# [[171.19925885]]
# [106.95821366]
# [[106.96680962]]
# [106.95820994]
# [[134.63851741]]
# [106.95820994]
# [[98.77413474]]
# [106.9582135]
# [[121.82066396]]
# [106.9582135]
